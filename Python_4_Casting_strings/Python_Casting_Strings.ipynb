# %% [markdown]
# **Casting:**
#
# Casting in python uses inbuilt functions:
#
# int() - constructs an integer number from an integer literal, a float literal (by removing all decimals), or a string literal (providing the string represents a whole number)
#
# float() - constructs a float number from an integer literal, a float literal or a string literal (providing the string represents a float or an integer)
#
# str() - constructs a string from a wide variety of data types, including strings, integer literals and float literals

# %% [markdown]
# **Integers:**

# %%
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3

print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Floats:

# %%
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2

print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.2

# %% [markdown]
# Strings :

# %%
x = str("sample") # x will be 's1'
y = str(2)    # y will be '2'
z = str(3.0)  # z will be '3.0'


print(x)
print(y)
print(z)

print(type(x))
print(type(y))
print(type(z))
# Out:
# sample
# 2
# 3.0
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# Strings
#
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello".
#
# You can display a string literal with the print() function:

# %%
print("Hello")
print('Hello')


x= "revathi"
print(x)

print('x')
# Out:
# Hello
# Hello
# revathi
# x

# %% [markdown]
# Assign String to a Variable
#
# Assigning a string to a variable is done with the variable name followed by an equal sign and the string:

# %%
a = "Hello"

x='ashwini'
print(a)
# Out:
# Hello

# %% [markdown]
# Multiline Strings:
#
# You can assign a multiline string to a variable by using three quotes:

# %%
"""example of multi line strings,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""

""" sjbdncbjfhdnbcdjkvhv"""


# the upper part is the multi line comments

# the below a variable is storing a multi line string
a = """example of multi line strings,
im passing
string 
in many lines """

a= ''' example of 
multi 
line 
strings'''

# %% [markdown]
# Or three single quotes:

# %%
a = '''example of multi line strings
Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua.'''
print(a)
# Out:
# example of multi line strings
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %% [markdown]
# Strings are Arrays
#
# a single character is simply a string with a length of 1.
#
# Square brackets can be used to access elements of the string.

# %%
x= "python"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(x[5])  # read it as x off 5
# Out:
# n

# %%
a = "Hello, World!1"
print(a[4])
print(a[11])
print(a[5])
print(a[13])

print(a[14]) #error for giving strings out of index .... indexes are 0,1,2....13
# Out:
# o
# d
# ,
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-4ee9d8362df8> in <cell line: 7>()
#       5 print(a[13])
#       6
# ----> 7 print(a[14]) #error for giving strings out of index .... indexes are 0,1,2....13
#
# IndexError: string index out of range

# %% [markdown]
# String Length:
#
# To get the length of a string, use the len() function.

# %%
a = "Hello, World"
print(len(a))
# Out:
# 12

# %% [markdown]
# Python - Slicing Strings:
#
# Slicing
# You can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string.

# %% [markdown]
# STRING[**FROM : TO -1**] ---- SYNTAX

# %%
b = "Hello, World!"


print(b[2])


print(b[2:5])  # it will print from 2 index to 4th index (because of 5-1)

print(b[2:8]) 

t= "i just had "

print(t[2:10])
# Out:
# l
# llo
# llo, W
# just had

# %% [markdown]
# **print From the 5th character**

# %%
b = "Hello, World!"
print(b[5:])
# Out:
# , World!

# %% [markdown]
# **Print the first five characters**

# %%
b = "Hello, World!"
print(b[:5])   #till the 5-1 = 4, so it will print till 4th character from the starting
# Out:
# Hello

# %% [markdown]
# Get the characters:
#
# HELLO, WORLD!
#
# COUNT FROM THE END...
#
# FROM 5TH CHARACTER **EXCLUDING 5TH CHARACTER**  ... BUT PRINT FROM BEGINNING of that charater number

# %% [markdown]
# ![slicing.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# as we did 2nd number -1 in the positive slicing but here we are doing 1st number-1 in the negative slicing.

# %%
b = "Hello, World!"
print(b[-5:])  # as it is negative indexing we have to do 5-1 =4 and we have to print from the ending 4th character
# Out:
# orld!

# %% [markdown]
# ![slicing_1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# HELLO, WORLD!
#
# **TO 5TH CHARACTER COUNT FROM THE END ... BUT PRINT FROM BEGINNING**

# %%
b = "Hello, World!"
print(b[:-5])
# Out:
# Hello, W

# %% [markdown]
# **Python - Modify Strings**
#
# upper case
#
# lower case
#
# remove spaces

# %%
a = "Hello, World!"
print(a.upper())   #len(a)
print(a)
# Out:
# HELLO, WORLD!
# Hello, World!

# %%
a = "Hello, World!"
print(a.lower())
# Out:
# hello, world!

# %%
#The strip() method removes any whitespace from the beginning or the end not in between:
a = " Hello, World!     "
print(a.strip()) # returns "Hello, World!"

print(a)
# Out:
# Hello, World!
#  Hello, World!

# %% [markdown]
# **String Concatenation**

# %%
a = "Hello"
b = "World"
c = a + b
print(c)
# Out:
# HelloWorld

# %%
a = "Hello"
b = "World"
c = a + " " + b
print(c)
# Out:
# Hello World

# %% [markdown]
# **Python - Format - Strings**

# %%
age = 16
txt = "My name is ramya, I am " + age   # it will throw error if you combine the strings and numbers by using + oeprator
print(txt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-93fa8720e168> in <cell line: 2>()
#       1 age = 16
# ----> 2 txt = "My name is ramya, I am " + age
#       3 print(txt)
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = 36

print("My name is Ramya, and I am {}".format(age))
# Out:
# My name is Ramya, and I am 36

# %%
#Method 1:
print('The value of pi is: {} and id is {} vxcvcxbfddff '.format(3.141592,12))
# Out:
# The value of pi is: 3.141592 and id is 12 vxcvcxbfddff

# %%
#Method 2:
print('The value of pi is: %f' %3.141592)
# Out:
# The value of pi is: 3.141592

# %% [markdown]
# **Escape Character**
#
# To insert characters that are illegal in a string, use an escape character.
#
# An escape character is a backslash \ followed by the character you want to insert.
#
# An example of an illegal character is a double quote inside a string that is surrounded by double quotes:

# %%
txt = "We are the so-called "Vikings" from the north."
# Out:
#   File "<ipython-input-33-56cdf4283a8e>", line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = 'We are the so-called "Vikings" from the north.'
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %% [markdown]
# To fix this problem, use the escape character \":

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %% [markdown]
# **List of Python - String Methods  ()**
#
# https://www.geeksforgeeks.org/python-string-methods/
