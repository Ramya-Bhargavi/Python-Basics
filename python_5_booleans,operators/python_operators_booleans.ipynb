# %% [markdown]
# **Python Booleans**

# %% [markdown]
# Booleans represent one of two values: True or False.

# %% [markdown]
# In programming you often need to know if an expression is True or False.
#
# You can evaluate any expression in Python, and get one of two answers, True or False.
#
# When you compare two values, the expression is evaluated and Python returns the Boolean answer:

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "Hello"
y = 15

print(bool(x))
print(bool(y))
# Out:
# True
# True

# %% [markdown]
# **Most Values are True**
#
# Almost any value is evaluated to True if it has some sort of content.
#
# Any string is True, except empty strings.
#
# Any number is True, except 0.
#
# Any list, tuple, set, and dictionary are True, except empty ones.

# %%
print(bool("abc"))
print(bool(123))
print(bool(["apple", "cherry", "banana"]))
# Out:
# True
# True
# True

# %%
print(bool(False))
print(bool(None))
print(bool(0))
print(bool(""))
print(bool(()))
print(bool([]))
print(bool({}))
# Out:
# False
# False
# False
# False
# False
# False
# False

# %% [markdown]
# **Python Operators**

# %% [markdown]
# Operators are used to perform operations on variables and values.
#
# In the example below, we use the + operator to add together two values:

# %%
print(10 + 5)
# Out:
# 15

# %% [markdown]
# Python divides the operators in the following groups:
#
# Arithmetic operators
#
# Assignment operators
#
# Comparison operators
#
# Logical operators
#
# Identity operators
#
# Membership operators
#
# Bitwise operators

# %% [markdown]
# **Python Arithmetic Operators**
# ![image.png](data:image/png;base64,...)

# %%
print(27/4)

print(27//4)

print(56/4) # normal division will give you decimal values

print(56//4)  # floor division will round the values to the lowest near integer
# Out:
# 6.75
# 6
# 14.0
# 14

# %% [markdown]
# **Python Assignment Operators**
#
# Assignment operators are used to assign values to variables:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=3
print(x)

y=x+5
print(y)

x=x+5  # x=3+5=8
print(x)


x+=5   #x=x+5   in above statement x is converted to 8, so here x will be x=8+5= 13
print(x)
# Out:
# 3
# 8
# 8
# 13

# %% [markdown]
# **Python Comparison Operators**
#
# Comparison operators are used to compare two values:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x =3
y= 3
print(x==y)

print(x != y) # not equal to operator

print(x<y)
# Out:
# True
# False
# False

# %% [markdown]
# **Python Logical Operators**
#
# Logical operators are used to combine conditional statements:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x=20
print(x<50 and x<100)

y=10
print(y<5 or y <30)
# Out:
# True
# True

# %% [markdown]
# **Python Identity Operators**
#
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Python Membership Operators**:
#
# Membership operators are used to test if a sequence is presented in an object:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Python Bitwise Operators**
#
# Bitwise operators are used to compare (binary) numbers:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Decimal to Binary Number:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Binary To decimal conversion:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Operators for binary numbers :**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(12 | 25)
# Out:
# 29

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print( 12 & 25)

x=12
y=25

print(x&y)
# Out:
# 8
# 8

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print( 12 ^ 25)
# Out:
# 21

# %% [markdown]
# **Operator Precedence:**
#
# Operator precedence describes the order in which operations are performed.

# %%
print((6 + 3) - (6 + 3))
print(100 + 5 * 3 ** 2)  

# highest order in the table below is exponentitaion i.e. ** so 3 power 2 = 9 will be calculated first
# next highest order is multiplication now 9*5 =45 will be calculated
#and next is + so 45+100 is calculated = 145
# Out:
# 0
# 145

# %% [markdown]
# The precedence order is described in the table below, starting with the highest precedence at the top:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(5 + 4 - 7 + 3)
# Out:
# 5
